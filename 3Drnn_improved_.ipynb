# %% [markdown]
# <a href="https://colab.research.google.com/github/Swethan-colab/Sonu27/blob/main/3Drnn_improved_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

path = "/content/drive/MyDrive/NLH.xlsx"
# Read the Excel file
df = pd.read_excel(path)

# Display the DataFrame
print(df)
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2
# 0           NaN       epsn    sigmaiso
# 1           NaN    0.00005    2.592593
# 2           NaN    0.00055   28.518519
# 3           NaN    0.00105   54.444444
# 4           NaN    0.00155   62.387902
# ..          ...        ...         ...
# 356         NaN    0.01755  168.331045
# 357         NaN    0.01805  168.789461
# 358         NaN    0.01855  169.247876
# 359         NaN    0.01905  169.706291
# 360         NaN    0.01955  170.164706
#
# [361 rows x 3 columns]

# %%
column_names = ['index', 'epsn', 'sigmaiso']  # Replace with your desired names
df.columns = column_names


# Assuming the column with NaN values is named 'Unnamed: 0'
df_ = df[['epsn', 'sigmaiso']]
df__ = df_.iloc[1:]
print(df__)
# Out:
#         epsn    sigmaiso
# 1    0.00005    2.592593
# 2    0.00055   28.518519
# 3    0.00105   54.444444
# 4    0.00155   62.387902
# 5    0.00205   64.874616
# ..       ...         ...
# 356  0.01755  168.331045
# 357  0.01805  168.789461
# 358  0.01855  169.247876
# 359  0.01905  169.706291
# 360  0.01955  170.164706
#
# [360 rows x 2 columns]

# %%
import torch

# Assuming 'df__' is your DataFrame
# Check for missing values
if df__['sigmaiso'].isnull().any():
    print("Warning: 'sigmaiso' column contains missing values (NaNs).")
    # Choose a solution: remove rows, impute missing values, etc.
    df__ = df__.dropna(subset=['sigmaiso'])  # Example: Remove rows with NaNs in 'sigmaiso'

# Check data types and convert to numeric if needed
if not pd.api.types.is_numeric_dtype(df__['sigmaiso']):
    print("Warning: 'sigmaiso' column may contain non-numerical data types.")
    # Use .loc to safely modify the column
    df__.loc[:, 'sigmaiso'] = pd.to_numeric(df__['sigmaiso'], errors='coerce')

# Assuming data is now clean
y = torch.from_numpy(df__['sigmaiso'].values.astype(np.float32)).unsqueeze(1)  # Convert to float32 for PyTorch
# Out:
# Warning: 'sigmaiso' column may contain non-numerical data types.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#Datacorrection in espn values

if df__['epsn'].isnull().any():
    print("Warning: 'sigmaiso' column contains missing values (NaNs).")
    # Choose a solution: remove rows, impute missing values, etc.
    df__ = df__.dropna(subset=['epsn'])  # Example: Remove rows with NaNs in 'sigmaiso'

# Check data types and convert to numeric if needed
if not pd.api.types.is_numeric_dtype(df__['epsn']):
    print("Warning: 'epsn' column may contain non-numerical data types.")
    # Use .loc to safely modify the column
    df__.loc[:, 'epsn'] = pd.to_numeric(df__['epsn'], errors='coerce')

# Assuming data is now clean
x = torch.from_numpy(df__['epsn'].values.astype(np.float32)).unsqueeze(1)  # Convert to float32 for PyTorch

sns.set_style("whitegrid")

plt.figure(figsize=(8, 6))  # Adjust figure size as needed

plt.plot(x, y, color='steelblue', linewidth=2)  # Customize line color and width

plt.xlabel('Strain', fontsize=12)
plt.ylabel('Stress', fontsize=12)
plt.title('Non-linear Combined Hardening', fontsize=14, fontweight='bold')

# Customize gridlines
plt.grid(color='lightgray', linestyle='--')

plt.tight_layout()  # Adjust spacing

plt.show()
# Out:
# Warning: 'epsn' column may contain non-numerical data types.

# %%
def normalize(data):
  """
  Normalizes data to a range of [0, 1].

  Args:
      data (torch.Tensor): The data to be normalized.

  Returns:
      torch.Tensor: The normalized data.
  """
  min_val = torch.min(data)
  max_val = torch.max(data)
  return (data - min_val) / (max_val - min_val)
def z_score(data):
  return (data - data.mean()) / data.std()

# %%
from sklearn.model_selection import train_test_split
X_train_val, X_test_, y_train_val, y_test_ = train_test_split(x, y, test_size=0.1, random_state=42,shuffle=False)

# Further split training and validation sets (from X_train_val and y_train_val)
X_train_, X_val_, y_train_, y_val_ = train_test_split(X_train_val, y_train_val, test_size=0.16, random_state=42, shuffle=False)

X_train = X_train_
X_val = X_val_
X_test = X_test_

y_train = normalize(y_train_)
y_val = normalize(y_val_)
y_test = normalize(y_test_)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# Assuming 'x' and 'y' are your PyTorch tensors
train_dataset = TensorDataset((X_train), (y_train))
val_dataset = TensorDataset((X_val), (y_val))
test_dataset = TensorDataset((X_test), (y_test))
batch_size=6000
# Create data loaders for each set
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
epochs = 1000

patience = 5  # Early stopping patience
learning_rate = 0.0008

# %%
import torch.nn as nn

class MyModel(nn.Module):
  def __init__(self):
    super(MyModel, self).__init__()
    self.gru1 = nn.GRU(input_size=1, hidden_size=32)
    self.gru2 = nn.GRU(input_size=32, hidden_size=16)
    self.linear = nn.Linear(16, 1)

  def forward(self, x):
    x = self.gru1(x)[0]  # Access hidden state from GRU1
    x = self.gru2(x)[0]  # Access hidden state from GRU2
    x = self.linear(x)
    return x

# Create the model
model = MyModel()



# Function to calculate loss for a given data loader
def calculate_loss(data_loader, model, loss_fn):
  total_loss = 0
  for data, target in data_loader:
    predicted_stress = model(data)
    loss = loss_fn(predicted_stress, target)
    total_loss += loss.item()
  return total_loss / len(data_loader)

# %%
def evaluate(model, val_dataloader, criterion):

    model.eval()  # Set model to evaluation mode (optional for some layers)
    with torch.no_grad():
        total_val_loss = 0
        for data, target in val_dataloader:
            output = model(data)
            val_loss = criterion(output, target)
            total_val_loss += val_loss.item()
    return total_val_loss / len(val_dataloader)

def train_model(model, train_loader, val_loader, epochs, patience):
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)  # Adjust optimizer
    criterion = nn.MSELoss()  # Mean Squared Error loss

    training_losses = []  # Store training losses for each epoch
    validation_losses = []  # Store validation losses for each epoch

    best_val_loss = float('inf')
    for epoch in range(epochs):
        # Train loop
        total_train_loss = 0
        for data, target in train_loader:
            optimizer.zero_grad()  # Reset gradients for each batch

            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

        # Calculate and print average training loss for the epoch
        avg_train_loss = total_train_loss / len(train_loader)
        training_losses.append(avg_train_loss)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.4f}")

        # Validation
        val_loss = evaluate(model, val_dataloader, criterion)
        validation_losses.append(val_loss)


        # Early stopping (implementation not shown here for brevity)

    # Plot training and validation loss (after training)
    sns.set_style("whitegrid")  # Set seaborn style for clean background

    plt.figure(figsize=(10, 6))  # Adjust figure size as needed

    plt.plot(range(epochs), training_losses, label='Training Loss', color='royalblue', linewidth=2)

    plt.yscale('log')  # Set y-axis to logarithmic scale
    plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)  # Update label to reflect log scale

    plt.grid(color='lightgray', linestyle='--')

    plt.legend(title='Loss Type', loc='upper left', bbox_to_anchor=(1, 1))

    plt.tight_layout()

    plt.show()

    # Load best model weights (implementation not shown here for brevity)
    return model

# %%
train_model(model,train_dataloader,val_dataloader,epochs,patience)
# Out:
# Epoch 1/1000, Train Loss: 0.2735
# Epoch 2/1000, Train Loss: 0.2610
# Epoch 3/1000, Train Loss: 0.2491
# Epoch 4/1000, Train Loss: 0.2378
# Epoch 5/1000, Train Loss: 0.2271
# Epoch 6/1000, Train Loss: 0.2170
# Epoch 7/1000, Train Loss: 0.2075
# Epoch 8/1000, Train Loss: 0.1987
# Epoch 9/1000, Train Loss: 0.1904
# Epoch 10/1000, Train Loss: 0.1829
# Epoch 11/1000, Train Loss: 0.1759
# Epoch 12/1000, Train Loss: 0.1697
# Epoch 13/1000, Train Loss: 0.1641
# Epoch 14/1000, Train Loss: 0.1591
# Epoch 15/1000, Train Loss: 0.1548
# Epoch 16/1000, Train Loss: 0.1512
# Epoch 17/1000, Train Loss: 0.1483
# Epoch 18/1000, Train Loss: 0.1460
# Epoch 19/1000, Train Loss: 0.1443
# Epoch 20/1000, Train Loss: 0.1432
# Epoch 21/1000, Train Loss: 0.1426
# Epoch 22/1000, Train Loss: 0.1425
# Epoch 23/1000, Train Loss: 0.1427
# Epoch 24/1000, Train Loss: 0.1432
# Epoch 25/1000, Train Loss: 0.1438
# Epoch 26/1000, Train Loss: 0.1445
# Epoch 27/1000, Train Loss: 0.1451
# Epoch 28/1000, Train Loss: 0.1456
# Epoch 29/1000, Train Loss: 0.1460
# Epoch 30/1000, Train Loss: 0.1461
# Epoch 31/1000, Train Loss: 0.1461
# Epoch 32/1000, Train Loss: 0.1458
# Epoch 33/1000, Train Loss: 0.1455
# Epoch 34/1000, Train Loss: 0.1450
# Epoch 35/1000, Train Loss: 0.1446
# Epoch 36/1000, Train Loss: 0.1441
# Epoch 37/1000, Train Loss: 0.1436
# Epoch 38/1000, Train Loss: 0.1432
# Epoch 39/1000, Train Loss: 0.1428
# Epoch 40/1000, Train Loss: 0.1425
# Epoch 41/1000, Train Loss: 0.1423
# Epoch 42/1000, Train Loss: 0.1422
# Epoch 43/1000, Train Loss: 0.1421
# Epoch 44/1000, Train Loss: 0.1420
# Epoch 45/1000, Train Loss: 0.1420
# Epoch 46/1000, Train Loss: 0.1421
# Epoch 47/1000, Train Loss: 0.1421
# Epoch 48/1000, Train Loss: 0.1422
# Epoch 49/1000, Train Loss: 0.1422
# Epoch 50/1000, Train Loss: 0.1423
# Epoch 51/1000, Train Loss: 0.1423
# Epoch 52/1000, Train Loss: 0.1423
# Epoch 53/1000, Train Loss: 0.1423
# Epoch 54/1000, Train Loss: 0.1423
# Epoch 55/1000, Train Loss: 0.1422
# Epoch 56/1000, Train Loss: 0.1422
# Epoch 57/1000, Train Loss: 0.1421
# Epoch 58/1000, Train Loss: 0.1421
# Epoch 59/1000, Train Loss: 0.1420
# Epoch 60/1000, Train Loss: 0.1420
# Epoch 600/1000, Train Loss: 0.0033
# Epoch 601/1000, Train Loss: 0.0038
# Epoch 602/1000, Train Loss: 0.0037
# Epoch 603/1000, Train Loss: 0.0032
# Epoch 604/1000, Train Loss: 0.0034
# Epoch 605/1000, Train Loss: 0.0036
# Epoch 606/1000, Train Loss: 0.0034
# Epoch 607/1000, Train Loss: 0.0032
# Epoch 608/1000, Train Loss: 0.0034
# Epoch 609/1000, Train Loss: 0.0035
# Epoch 610/1000, Train Loss: 0.0032
# Epoch 611/1000, Train Loss: 0.0033
# Epoch 612/1000, Train Loss: 0.0034
# Epoch 613/1000, Train Loss: 0.0032
# Epoch 614/1000, Train Loss: 0.0032
# Epoch 615/1000, Train Loss: 0.0033
# Epoch 616/1000, Train Loss: 0.0033
# Epoch 617/1000, Train Loss: 0.0032
# Epoch 618/1000, Train Loss: 0.0032
# Epoch 619/1000, Train Loss: 0.0032
# Epoch 620/1000, Train Loss: 0.0032
# Epoch 621/1000, Train Loss: 0.0032
# Epoch 622/1000, Train Loss: 0.0032
# Epoch 623/1000, Train Loss: 0.0032
# Epoch 624/1000, Train Loss: 0.0031
# Epoch 625/1000, Train Loss: 0.0032
# Epoch 626/1000, Train Loss: 0.0032
# Epoch 627/1000, Train Loss: 0.0031
# Epoch 628/1000, Train Loss: 0.0031
# Epoch 629/1000, Train Loss: 0.0032
# Epoch 630/1000, Train Loss: 0.0031
# Epoch 631/1000, Train Loss: 0.0031
# Epoch 632/1000, Train Loss: 0.0031
# Epoch 633/1000, Train Loss: 0.0031
# Epoch 634/1000, Train Loss: 0.0031
# Epoch 635/1000, Train Loss: 0.0031
# Epoch 636/1000, Train Loss: 0.0031
# Epoch 637/1000, Train Loss: 0.0031
# Epoch 638/1000, Train Loss: 0.0031
# Epoch 639/1000, Train Loss: 0.0031
# Epoch 640/1000, Train Loss: 0.0031
# Epoch 641/1000, Train Loss: 0.0031
# Epoch 642/1000, Train Loss: 0.0031
# Epoch 643/1000, Train Loss: 0.0031
# Epoch 644/1000, Train Loss: 0.0031
# Epoch 645/1000, Train Loss: 0.0031
# Epoch 646/1000, Train Loss: 0.0031
# Epoch 647/1000, Train Loss: 0.0031
# Epoch 648/1000, Train Loss: 0.0031
# Epoch 649/1000, Train Loss: 0.0031
# Epoch 650/1000, Train Loss: 0.0031
# Epoch 651/1000, Train Loss: 0.0031
# Epoch 652/1000, Train Loss: 0.0031
# Epoch 653/1000, Train Loss: 0.0031
# Epoch 654/1000, Train Loss: 0.0031
# Epoch 655/1000, Train Loss: 0.0031
# Epoch 656/1000, Train Loss: 0.0031
# Epoch 657/1000, Train Loss: 0.0031
# Epoch 658/1000, Train Loss: 0.0031
# Epoch 659/1000, Train Loss: 0.0031
# Epoch 660/1000, Train Loss: 0.0030
# Epoch 661/1000, Train Loss: 0.0030
# Epoch 662/1000, Train Loss: 0.0030
# Epoch 663/1000, Train Loss: 0.0030
# Epoch 664/1000, Train Loss: 0.0030
# Epoch 665/1000, Train Loss: 0.0030
# Epoch 666/1000, Train Loss: 0.0030
# Epoch 667/1000, Train Loss: 0.0030
# Epoch 735/1000, Train Loss: 0.0029
# Epoch 736/1000, Train Loss: 0.0029
# Epoch 737/1000, Train Loss: 0.0029
# Epoch 738/1000, Train Loss: 0.0029
# Epoch 739/1000, Train Loss: 0.0029
# Epoch 740/1000, Train Loss: 0.0029
# Epoch 741/1000, Train Loss: 0.0029
# Epoch 742/1000, Train Loss: 0.0029
# Epoch 743/1000, Train Loss: 0.0029
# Epoch 744/1000, Train Loss: 0.0029
# Epoch 745/1000, Train Loss: 0.0029
# Epoch 746/1000, Train Loss: 0.0029
# Epoch 747/1000, Train Loss: 0.0029
# Epoch 748/1000, Train Loss: 0.0029
# Epoch 749/1000, Train Loss: 0.0029
# Epoch 750/1000, Train Loss: 0.0029
# Epoch 751/1000, Train Loss: 0.0029
# Epoch 752/1000, Train Loss: 0.0029
# Epoch 753/1000, Train Loss: 0.0029
# Epoch 754/1000, Train Loss: 0.0029
# Epoch 755/1000, Train Loss: 0.0029
# Epoch 756/1000, Train Loss: 0.0029
# Epoch 757/1000, Train Loss: 0.0029
# Epoch 758/1000, Train Loss: 0.0029
# Epoch 759/1000, Train Loss: 0.0029
# Epoch 760/1000, Train Loss: 0.0029
# Epoch 761/1000, Train Loss: 0.0029
# Epoch 762/1000, Train Loss: 0.0029
# Epoch 763/1000, Train Loss: 0.0029
# Epoch 764/1000, Train Loss: 0.0029
# Epoch 765/1000, Train Loss: 0.0029
# Epoch 766/1000, Train Loss: 0.0029
# Epoch 767/1000, Train Loss: 0.0029
# Epoch 768/1000, Train Loss: 0.0029
# Epoch 769/1000, Train Loss: 0.0029
# Epoch 770/1000, Train Loss: 0.0029
# Epoch 771/1000, Train Loss: 0.0029
# Epoch 772/1000, Train Loss: 0.0029
# Epoch 773/1000, Train Loss: 0.0029
# Epoch 774/1000, Train Loss: 0.0029
# Epoch 775/1000, Train Loss: 0.0029
# Epoch 776/1000, Train Loss: 0.0029
# Epoch 777/1000, Train Loss: 0.0029
# Epoch 778/1000, Train Loss: 0.0029
# Epoch 779/1000, Train Loss: 0.0029
# Epoch 780/1000, Train Loss: 0.0029
# Epoch 781/1000, Train Loss: 0.0029
# Epoch 782/1000, Train Loss: 0.0029
# Epoch 783/1000, Train Loss: 0.0029
# Epoch 784/1000, Train Loss: 0.0029
# Epoch 785/1000, Train Loss: 0.0029
# Epoch 786/1000, Train Loss: 0.0029
# Epoch 787/1000, Train Loss: 0.0029
# Epoch 788/1000, Train Loss: 0.0029
# Epoch 789/1000, Train Loss: 0.0029
# Epoch 790/1000, Train Loss: 0.0029
# Epoch 791/1000, Train Loss: 0.0029
# Epoch 792/1000, Train Loss: 0.0029
# Epoch 793/1000, Train Loss: 0.0029
# Epoch 794/1000, Train Loss: 0.0029
# Epoch 795/1000, Train Loss: 0.0029
# Epoch 796/1000, Train Loss: 0.0029
# Epoch 797/1000, Train Loss: 0.0029
# Epoch 798/1000, Train Loss: 0.0029
# Epoch 799/1000, Train Loss: 0.0029
# Epoch 800/1000, Train Loss: 0.0029
# Epoch 801/1000, Train Loss: 0.0029
# Epoch 802/1000, Train Loss: 0.0029
# Epoch 803/1000, Train Loss: 0.0029
# Epoch 804/1000, Train Loss: 0.0029
# Epoch 805/1000, Train Loss: 0.0029
# Epoch 806/1000, Train Loss: 0.0029
# Epoch 807/1000, Train Loss: 0.0029
# Epoch 808/1000, Train Loss: 0.0029
# Epoch 809/1000, Train Loss: 0.0029
# Epoch 810/1000, Train Loss: 0.0029
# Epoch 811/1000, Train Loss: 0.0029
# Epoch 812/1000, Train Loss: 0.0029
# Epoch 813/1000, Train Loss: 0.0029
# Epoch 814/1000, Train Loss: 0.0029
# Epoch 815/1000, Train Loss: 0.0029
# Epoch 816/1000, Train Loss: 0.0029
# Epoch 817/1000, Train Loss: 0.0029
# Epoch 818/1000, Train Loss: 0.0029
# Epoch 819/1000, Train Loss: 0.0029
# Epoch 820/1000, Train Loss: 0.0029
# Epoch 821/1000, Train Loss: 0.0029
# Epoch 822/1000, Train Loss: 0.0029
# Epoch 823/1000, Train Loss: 0.0029
# Epoch 824/1000, Train Loss: 0.0029
# Epoch 825/1000, Train Loss: 0.0029
# Epoch 826/1000, Train Loss: 0.0029
# Epoch 827/1000, Train Loss: 0.0029
# Epoch 828/1000, Train Loss: 0.0029
# Epoch 829/1000, Train Loss: 0.0029
# Epoch 830/1000, Train Loss: 0.0029
# Epoch 831/1000, Train Loss: 0.0029
# Epoch 832/1000, Train Loss: 0.0029
# Epoch 833/1000, Train Loss: 0.0029
# Epoch 834/1000, Train Loss: 0.0029
# Epoch 835/1000, Train Loss: 0.0029
# Epoch 836/1000, Train Loss: 0.0030
# Epoch 837/1000, Train Loss: 0.0031
# Epoch 838/1000, Train Loss: 0.0033
# Epoch 839/1000, Train Loss: 0.0035
# Epoch 840/1000, Train Loss: 0.0039
# Epoch 841/1000, Train Loss: 0.0038
# Epoch 842/1000, Train Loss: 0.0037
# Epoch 843/1000, Train Loss: 0.0032
# Epoch 844/1000, Train Loss: 0.0029
# Epoch 845/1000, Train Loss: 0.0029
# Epoch 846/1000, Train Loss: 0.0032
# Epoch 847/1000, Train Loss: 0.0034
# Epoch 848/1000, Train Loss: 0.0032
# Epoch 849/1000, Train Loss: 0.0029
# Epoch 850/1000, Train Loss: 0.0028
# Epoch 851/1000, Train Loss: 0.0030
# Epoch 852/1000, Train Loss: 0.0031
# Epoch 853/1000, Train Loss: 0.0030
# Epoch 854/1000, Train Loss: 0.0029
# Epoch 855/1000, Train Loss: 0.0028
# Epoch 856/1000, Train Loss: 0.0029
# Epoch 857/1000, Train Loss: 0.0030
# Epoch 858/1000, Train Loss: 0.0029
# Epoch 859/1000, Train Loss: 0.0028
# Epoch 860/1000, Train Loss: 0.0028
# Epoch 861/1000, Train Loss: 0.0029
# Epoch 862/1000, Train Loss: 0.0029
# Epoch 863/1000, Train Loss: 0.0029
# Epoch 864/1000, Train Loss: 0.0028
# Epoch 865/1000, Train Loss: 0.0028
# Epoch 866/1000, Train Loss: 0.0029
# Epoch 867/1000, Train Loss: 0.0029
# Epoch 868/1000, Train Loss: 0.0028
# Epoch 869/1000, Train Loss: 0.0028
# Epoch 937/1000, Train Loss: 0.0028
# Epoch 938/1000, Train Loss: 0.0028
# Epoch 939/1000, Train Loss: 0.0028
# Epoch 940/1000, Train Loss: 0.0028
# Epoch 941/1000, Train Loss: 0.0028
# Epoch 942/1000, Train Loss: 0.0028
# Epoch 943/1000, Train Loss: 0.0028
# Epoch 944/1000, Train Loss: 0.0028
# Epoch 945/1000, Train Loss: 0.0028
# Epoch 946/1000, Train Loss: 0.0027
# Epoch 947/1000, Train Loss: 0.0027
# Epoch 948/1000, Train Loss: 0.0027
# Epoch 949/1000, Train Loss: 0.0027
# Epoch 950/1000, Train Loss: 0.0027
# Epoch 951/1000, Train Loss: 0.0027
# Epoch 952/1000, Train Loss: 0.0027
# Epoch 953/1000, Train Loss: 0.0027
# Epoch 954/1000, Train Loss: 0.0027
# Epoch 955/1000, Train Loss: 0.0027
# Epoch 956/1000, Train Loss: 0.0027
# Epoch 957/1000, Train Loss: 0.0027
# Epoch 958/1000, Train Loss: 0.0027
# Epoch 959/1000, Train Loss: 0.0027
# Epoch 960/1000, Train Loss: 0.0027
# Epoch 961/1000, Train Loss: 0.0027
# Epoch 962/1000, Train Loss: 0.0027
# Epoch 963/1000, Train Loss: 0.0027
# Epoch 964/1000, Train Loss: 0.0027
# Epoch 965/1000, Train Loss: 0.0027
# Epoch 966/1000, Train Loss: 0.0027
# Epoch 967/1000, Train Loss: 0.0027
# Epoch 968/1000, Train Loss: 0.0027
# Epoch 969/1000, Train Loss: 0.0027
# Epoch 970/1000, Train Loss: 0.0027
# Epoch 971/1000, Train Loss: 0.0027
# Epoch 972/1000, Train Loss: 0.0027
# Epoch 973/1000, Train Loss: 0.0027
# Epoch 974/1000, Train Loss: 0.0027
# Epoch 975/1000, Train Loss: 0.0027
# Epoch 976/1000, Train Loss: 0.0027
# Epoch 977/1000, Train Loss: 0.0027
# Epoch 978/1000, Train Loss: 0.0027
# Epoch 979/1000, Train Loss: 0.0027
# Epoch 980/1000, Train Loss: 0.0027
# Epoch 981/1000, Train Loss: 0.0027
# Epoch 982/1000, Train Loss: 0.0027
# Epoch 983/1000, Train Loss: 0.0026
# Epoch 984/1000, Train Loss: 0.0026
# Epoch 985/1000, Train Loss: 0.0026
# Epoch 986/1000, Train Loss: 0.0026
# Epoch 987/1000, Train Loss: 0.0026
# Epoch 988/1000, Train Loss: 0.0026
# Epoch 989/1000, Train Loss: 0.0026
# Epoch 990/1000, Train Loss: 0.0026
# Epoch 991/1000, Train Loss: 0.0026
# Epoch 992/1000, Train Loss: 0.0026
# Epoch 993/1000, Train Loss: 0.0026
# Epoch 994/1000, Train Loss: 0.0026
# Epoch 995/1000, Train Loss: 0.0026
# Epoch 996/1000, Train Loss: 0.0026
# Epoch 997/1000, Train Loss: 0.0026
# Epoch 998/1000, Train Loss: 0.0026
# Epoch 999/1000, Train Loss: 0.0026
# Epoch 1000/1000, Train Loss: 0.0026
# MyModel(
#   (gru1): GRU(1, 32)
#   (gru2): GRU(32, 16)
#   (linear): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
test_loss = evaluate(model,test_dataloader,criterion)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 0.1817
